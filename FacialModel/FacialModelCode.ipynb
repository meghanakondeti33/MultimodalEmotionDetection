# %%
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
import os
import pandas as pd
import numpy as np

# %%
TRAIN_DIR = '../images/train'
TEST_DIR = '../images/test'

# %%
import os
import pandas as pd
import numpy as np

def createdataframe(dir):
    image_paths = []
    labels = []

    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir, label)):
            image_paths.append(os.path.join(dir, label, imagename))
            labels.append(label)

    return image_paths, labels

train = pd.DataFrame()
train['image'], train['label'] = createdataframe('../images/train')

test = pd.DataFrame()
test['image'], test['label'] = createdataframe('../images/test')

print(train.head(10))
print(test.head(10))
print(train['label'].value_counts())
print(test['label'].value_counts())
# Out:
#                              image  label
# 0      ../images/train\Angry\0.png  Angry
# 1      ../images/train\Angry\1.png  Angry
# 2     ../images/train\Angry\10.png  Angry
# 3  ../images/train\Angry\10002.png  Angry
# 4  ../images/train\Angry\10016.png  Angry
# 5  ../images/train\Angry\10037.png  Angry
# 6  ../images/train\Angry\10038.png  Angry
# 7  ../images/train\Angry\10052.png  Angry
# 8  ../images/train\Angry\10057.png  Angry
# 9  ../images/train\Angry\10063.png  Angry
#                             image  label
# 0  ../images/test\Angry\32298.png  Angry
# 1  ../images/test\Angry\32303.png  Angry
# 2  ../images/test\Angry\32306.png  Angry
# 3  ../images/test\Angry\32312.png  Angry
# 4  ../images/test\Angry\32320.png  Angry
# 5  ../images/test\Angry\32331.png  Angry
# 6  ../images/test\Angry\32335.png  Angry
# 7  ../images/test\Angry\32336.png  Angry
# 8  ../images/test\Angry\32352.png  Angry
# 9  ../images/test\Angry\32362.png  Angry
# label
# Happy       7215
# Neutral     4965
# Sad         4830
# Fear        4097
# Angry       3995
# Surprise    3171
# Disgust      436
# Name: count, dtype: int64
# label
# Happy       879
# Neutral     626
# Sad         594
# Fear        528
# Angry       491
# Surprise    416
# Disgust      55
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

le = LabelEncoder()
le.fit(train['label'])

y_train = to_categorical(
    le.transform(train['label']),
    num_classes=7
)

y_test = to_categorical(
    le.transform(test['label']),
    num_classes=7
)

np.save('y_train_exact.npy', y_train)
np.save('y_test_exact.npy', y_test)

print(y_train.shape)
print(y_test.shape)
# Out:
# (28709, 7)
# (3589, 7)

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
import os

print("Current directory:", os.getcwd())
print("images/train exists:", os.path.exists("images/train"))
# Out:
# Current directory: c:\Users\CSE\Desktop\Multi_Model_Emotion_Detection\FacialModel
# images/train exists: False

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# Angry completed
# Disgust completed
# Fear completed
# Happy completed
# Neutral completed
# Sad completed
# Surprise completed

# %%
print(train)
# Out:
#                                    image     label
# 0            ../images/train\Angry\0.png     Angry
# 1            ../images/train\Angry\1.png     Angry
# 2           ../images/train\Angry\10.png     Angry
# 3        ../images/train\Angry\10002.png     Angry
# 4        ../images/train\Angry\10016.png     Angry
# ...                                  ...       ...
# 28704  ../images/train\Surprise\9969.png  Surprise
# 28705  ../images/train\Surprise\9985.png  Surprise
# 28706  ../images/train\Surprise\9990.png  Surprise
# 28707  ../images/train\Surprise\9992.png  Surprise
# 28708  ../images/train\Surprise\9996.png  Surprise
#
# [28709 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# Angry completed
# Disgust completed
# Fear completed
# Happy completed
# Neutral completed
# Sad completed
# Surprise completed

# %%
print(test)
print(test['image'])
# Out:
#                                   image     label
# 0        ../images/test\Angry\32298.png     Angry
# 1        ../images/test\Angry\32303.png     Angry
# 2        ../images/test\Angry\32306.png     Angry
# 3        ../images/test\Angry\32312.png     Angry
# 4        ../images/test\Angry\32320.png     Angry
# ...                                 ...       ...
# 3584  ../images/test\Surprise\35857.png  Surprise
# 3585  ../images/test\Surprise\35863.png  Surprise
# 3586  ../images/test\Surprise\35872.png  Surprise
# 3587  ../images/test\Surprise\35874.png  Surprise
# 3588  ../images/test\Surprise\35875.png  Surprise
#
# [3589 rows x 2 columns]
# 0          ../images/test\Angry\32298.png
# 1          ../images/test\Angry\32303.png
# 2          ../images/test\Angry\32306.png
# 3          ../images/test\Angry\32312.png
# 4          ../images/test\Angry\32320.png
#                       ...
# 3584    ../images/test\Surprise\35857.png
# 3585    ../images/test\Surprise\35863.png
# 3586    ../images/test\Surprise\35872.png
# 3587    ../images/test\Surprise\35874.png
# 3588    ../images/test\Surprise\35875.png
# Name: image, Length: 3589, dtype: str

# %%
from tqdm.notebook import tqdm

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, color_mode='grayscale')
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features), 48, 48, 1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28709 [00:00<?, ?it/s]

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/3589 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
import numpy as np

# Save training data into one file
np.savez("train_data.npz", x_train=x_train, y_train=y_train)

# Save testing data into one file
np.savez("test_data.npz", x_test=x_test, y_test=y_test)

print("Preprocessed data saved successfully into single files!")
# Out:
# Preprocessed data saved successfully into single files!

# %%
model = Sequential()
# convolutional layers
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())
# fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
# output layer
model.add(Dense(7, activation='softmax'))

# %%
# model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = 'accuracy' )
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
import tensorflow as tf

print("TensorFlow:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
print("CPUs:", tf.config.list_physical_devices('CPU'))
# Out:
# TensorFlow: 2.21.0
# GPUs: []
# CPUs: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=128,
    epochs=1,
    validation_data=(x_test, y_test)
)
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 131s 571ms/step - accuracy: 0.2455 - loss: 1.8246 - val_accuracy: 0.2449 - val_loss: 1.8161

# %%
import tensorflow as tf
with tf.device('/GPU:0'):
    model.fit(x= x_train,y = y_train, batch_size = 128, epochs = 100, validation_data = (x_test,y_test))
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741808675.902590    1416 service.cc:148] XLA service 0x558bc4ade1d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741808675.904200    1416 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2050, Compute Capability 8.6
# 2025-03-12 19:44:36.186496: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1741808676.913225    1416 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-03-12 19:44:39.095303: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3063', 12 bytes spill stores, 16 bytes spill loads
#
# 2025-03-12 19:44:44.930086: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-03-12 19:44:52.569834: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# I0000 00:00:1741808698.332233    1416 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 224/225 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.2397 - loss: 1.8352
# 2025-03-12 19:45:33.697709: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.23GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.2398 - loss: 1.8352
# 2025-03-12 19:45:42.536070: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_112_0', 768 bytes spill stores, 720 bytes spill loads
#
# 2025-03-12 19:45:42.780053: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_112_0', 228 bytes spill stores, 228 bytes spill loads
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 81s 239ms/step - accuracy: 0.2398 - loss: 1.8351 - val_accuracy: 0.2471 - val_loss: 1.8129
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 127ms/step - accuracy: 0.2525 - loss: 1.8063 - val_accuracy: 0.2548 - val_loss: 1.7951
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 127ms/step - accuracy: 0.2638 - loss: 1.7743 - val_accuracy: 0.3133 - val_loss: 1.6620
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.3247 - loss: 1.6723 - val_accuracy: 0.4092 - val_loss: 1.5059
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.3982 - loss: 1.5465 - val_accuracy: 0.4537 - val_loss: 1.4069
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.4309 - loss: 1.4684 - val_accuracy: 0.4859 - val_loss: 1.3362
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.4516 - loss: 1.4204 - val_accuracy: 0.4976 - val_loss: 1.2888
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.4758 - loss: 1.3713 - val_accuracy: 0.5132 - val_loss: 1.2529
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.4833 - loss: 1.3427 - val_accuracy: 0.5150 - val_loss: 1.2425
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.4949 - loss: 1.3230 - val_accuracy: 0.5295 - val_loss: 1.2221
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - accuracy: 0.5055 - loss: 1.2907 - val_accuracy: 0.5373 - val_loss: 1.2013
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 127ms/step - accuracy: 0.5165 - loss: 1.2670 - val_accuracy: 0.5424 - val_loss: 1.1876
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5188 - loss: 1.2621 - val_accuracy: 0.5453 - val_loss: 1.1752
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.5260 - loss: 1.2435 - val_accuracy: 0.5541 - val_loss: 1.1622
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5314 - loss: 1.2271 - val_accuracy: 0.5582 - val_loss: 1.1405
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 41s 124ms/step - accuracy: 0.5411 - loss: 1.2135 - val_accuracy: 0.5687 - val_loss: 1.1333
# Epoch 17/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5460 - loss: 1.1924 - val_accuracy: 0.5651 - val_loss: 1.1286
# Epoch 18/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5559 - loss: 1.1818 - val_accuracy: 0.5722 - val_loss: 1.1072
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5585 - loss: 1.1736 - val_accuracy: 0.5723 - val_loss: 1.1151
# Epoch 20/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5661 - loss: 1.1578 - val_accuracy: 0.5790 - val_loss: 1.1038
# Epoch 21/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.5613 - loss: 1.1622 - val_accuracy: 0.5759 - val_loss: 1.0983
# Epoch 22/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5671 - loss: 1.1332 - val_accuracy: 0.5780 - val_loss: 1.0925
# Epoch 23/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5721 - loss: 1.1294 - val_accuracy: 0.5809 - val_loss: 1.0923
# Epoch 24/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.5738 - loss: 1.1266 - val_accuracy: 0.5805 - val_loss: 1.0915
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.5802 - loss: 1.1049 - val_accuracy: 0.5740 - val_loss: 1.0952
# Epoch 26/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5863 - loss: 1.1094 - val_accuracy: 0.5908 - val_loss: 1.0720
# Epoch 27/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5951 - loss: 1.0944 - val_accuracy: 0.5953 - val_loss: 1.0601
# Epoch 28/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5897 - loss: 1.0919 - val_accuracy: 0.5949 - val_loss: 1.0656
# Epoch 29/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.5912 - loss: 1.0755 - val_accuracy: 0.5929 - val_loss: 1.0646
# Epoch 30/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5958 - loss: 1.0765 - val_accuracy: 0.5880 - val_loss: 1.0713
# Epoch 31/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5958 - loss: 1.0645 - val_accuracy: 0.6007 - val_loss: 1.0551
# Epoch 32/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.5995 - loss: 1.0600 - val_accuracy: 0.6002 - val_loss: 1.0552
# Epoch 33/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6080 - loss: 1.0420 - val_accuracy: 0.6035 - val_loss: 1.0448
# Epoch 34/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6101 - loss: 1.0448 - val_accuracy: 0.6041 - val_loss: 1.0432
# Epoch 35/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6087 - loss: 1.0401 - val_accuracy: 0.6048 - val_loss: 1.0404
# Epoch 36/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6158 - loss: 1.0298 - val_accuracy: 0.6085 - val_loss: 1.0433
# Epoch 37/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6158 - loss: 1.0257 - val_accuracy: 0.6057 - val_loss: 1.0361
# Epoch 38/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6153 - loss: 1.0234 - val_accuracy: 0.6059 - val_loss: 1.0397
# Epoch 39/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6200 - loss: 1.0129 - val_accuracy: 0.6095 - val_loss: 1.0362
# Epoch 40/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6266 - loss: 0.9969 - val_accuracy: 0.6073 - val_loss: 1.0292
# Epoch 41/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.6229 - loss: 1.0077 - val_accuracy: 0.6098 - val_loss: 1.0364
# Epoch 42/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6278 - loss: 0.9826 - val_accuracy: 0.6092 - val_loss: 1.0358
# Epoch 43/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.6330 - loss: 0.9886 - val_accuracy: 0.6101 - val_loss: 1.0296
# Epoch 44/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6295 - loss: 0.9844 - val_accuracy: 0.6172 - val_loss: 1.0337
# Epoch 45/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6392 - loss: 0.9696 - val_accuracy: 0.6108 - val_loss: 1.0292
# Epoch 46/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6386 - loss: 0.9676 - val_accuracy: 0.6135 - val_loss: 1.0308
# Epoch 47/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6403 - loss: 0.9666 - val_accuracy: 0.6088 - val_loss: 1.0288
# Epoch 48/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 123ms/step - accuracy: 0.6334 - loss: 0.9718 - val_accuracy: 0.6084 - val_loss: 1.0376
# Epoch 49/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6434 - loss: 0.9648 - val_accuracy: 0.6138 - val_loss: 1.0268
# Epoch 50/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6458 - loss: 0.9456 - val_accuracy: 0.6126 - val_loss: 1.0293
# Epoch 51/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6516 - loss: 0.9332 - val_accuracy: 0.6151 - val_loss: 1.0242
# Epoch 52/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6492 - loss: 0.9475 - val_accuracy: 0.6198 - val_loss: 1.0202
# Epoch 53/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 41s 125ms/step - accuracy: 0.6542 - loss: 0.9261 - val_accuracy: 0.6209 - val_loss: 1.0226
# Epoch 54/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6543 - loss: 0.9238 - val_accuracy: 0.6173 - val_loss: 1.0221
# Epoch 55/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6603 - loss: 0.9153 - val_accuracy: 0.6194 - val_loss: 1.0228
# Epoch 56/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6608 - loss: 0.9143 - val_accuracy: 0.6183 - val_loss: 1.0285
# Epoch 57/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 42s 126ms/step - accuracy: 0.6562 - loss: 0.9295 - val_accuracy: 0.6212 - val_loss: 1.0151
# Epoch 58/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6680 - loss: 0.9043 - val_accuracy: 0.6151 - val_loss: 1.0183
# Epoch 59/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6666 - loss: 0.8988 - val_accuracy: 0.6211 - val_loss: 1.0117
# Epoch 60/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6667 - loss: 0.9099 - val_accuracy: 0.6172 - val_loss: 1.0179
# Epoch 61/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6728 - loss: 0.8892 - val_accuracy: 0.6239 - val_loss: 1.0169
# Epoch 62/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6765 - loss: 0.8745 - val_accuracy: 0.6229 - val_loss: 1.0174
# Epoch 63/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6770 - loss: 0.8771 - val_accuracy: 0.6195 - val_loss: 1.0207
# Epoch 64/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 42s 128ms/step - accuracy: 0.6767 - loss: 0.8813 - val_accuracy: 0.6130 - val_loss: 1.0233
# Epoch 65/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6890 - loss: 0.8468 - val_accuracy: 0.6245 - val_loss: 1.0074
# Epoch 66/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6840 - loss: 0.8560 - val_accuracy: 0.6251 - val_loss: 1.0213
# Epoch 67/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6767 - loss: 0.8624 - val_accuracy: 0.6226 - val_loss: 1.0231
# Epoch 68/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6823 - loss: 0.8669 - val_accuracy: 0.6229 - val_loss: 1.0226
# Epoch 69/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6891 - loss: 0.8475 - val_accuracy: 0.6244 - val_loss: 1.0091
# Epoch 70/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6891 - loss: 0.8384 - val_accuracy: 0.6243 - val_loss: 1.0219
# Epoch 71/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6954 - loss: 0.8290 - val_accuracy: 0.6272 - val_loss: 1.0213
# Epoch 72/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6927 - loss: 0.8317 - val_accuracy: 0.6216 - val_loss: 1.0156
# Epoch 73/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 124ms/step - accuracy: 0.6924 - loss: 0.8281 - val_accuracy: 0.6254 - val_loss: 1.0216
# Epoch 74/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.6900 - loss: 0.8354 - val_accuracy: 0.6315 - val_loss: 1.0156
# Epoch 75/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.7018 - loss: 0.8098 - val_accuracy: 0.6307 - val_loss: 1.0255
# Epoch 76/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 126ms/step - accuracy: 0.7035 - loss: 0.8028 - val_accuracy: 0.6293 - val_loss: 1.0159
# Epoch 77/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.7048 - loss: 0.8020 - val_accuracy: 0.6252 - val_loss: 1.0126
# Epoch 78/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 127ms/step - accuracy: 0.7035 - loss: 0.8045 - val_accuracy: 0.6314 - val_loss: 1.0188
# Epoch 79/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.7047 - loss: 0.8011 - val_accuracy: 0.6308 - val_loss: 1.0254
# Epoch 80/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 29s 130ms/step - accuracy: 0.7101 - loss: 0.7956 - val_accuracy: 0.6310 - val_loss: 1.0254
# Epoch 81/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 125ms/step - accuracy: 0.7094 - loss: 0.7965 - val_accuracy: 0.6312 - val_loss: 1.0091
# Epoch 82/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 42s 127ms/step - accuracy: 0.7092 - loss: 0.7974 - val_accuracy: 0.6265 - val_loss: 1.0193
# Epoch 83/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 28s 122ms/step - accuracy: 0.7094 - loss: 0.7852 - val_accuracy: 0.6312 - val_loss: 1.0197
# Epoch 84/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - accuracy: 0.7116 - loss: 0.7905 - val_accuracy: 0.6360 - val_loss: 1.0208
# Epoch 85/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.7137 - loss: 0.7844 - val_accuracy: 0.6265 - val_loss: 1.0346
# Epoch 86/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.7152 - loss: 0.7785 - val_accuracy: 0.6330 - val_loss: 1.0106
# Epoch 87/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - accuracy: 0.7218 - loss: 0.7697 - val_accuracy: 0.6290 - val_loss: 1.0220
# Epoch 88/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 25s 111ms/step - accuracy: 0.7243 - loss: 0.7540 - val_accuracy: 0.6349 - val_loss: 1.0200
# Epoch 89/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.7231 - loss: 0.7631 - val_accuracy: 0.6330 - val_loss: 1.0238
# Epoch 90/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - accuracy: 0.7209 - loss: 0.7661 - val_accuracy: 0.6308 - val_loss: 1.0263
# Epoch 91/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 109ms/step - accuracy: 0.7315 - loss: 0.7406 - val_accuracy: 0.6296 - val_loss: 1.0433
# Epoch 92/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 23s 104ms/step - accuracy: 0.7250 - loss: 0.7488 - val_accuracy: 0.6271 - val_loss: 1.0359
# Epoch 93/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 106ms/step - accuracy: 0.7266 - loss: 0.7465 - val_accuracy: 0.6358 - val_loss: 1.0193
# Epoch 94/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - accuracy: 0.7213 - loss: 0.7590 - val_accuracy: 0.6326 - val_loss: 1.0278
# Epoch 95/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 25s 110ms/step - accuracy: 0.7336 - loss: 0.7415 - val_accuracy: 0.6356 - val_loss: 1.0253
# Epoch 96/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - accuracy: 0.7393 - loss: 0.7242 - val_accuracy: 0.6337 - val_loss: 1.0367
# Epoch 97/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 24s 105ms/step - accuracy: 0.7346 - loss: 0.7404 - val_accuracy: 0.6392 - val_loss: 1.0176
# Epoch 98/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 23s 102ms/step - accuracy: 0.7345 - loss: 0.7239 - val_accuracy: 0.6386 - val_loss: 1.0342
# Epoch 99/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 23s 102ms/step - accuracy: 0.7368 - loss: 0.7308 - val_accuracy: 0.6367 - val_loss: 1.0249
# Epoch 100/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 23s 102ms/step - accuracy: 0.7379 - loss: 0.7237 - val_accuracy: 0.6362 - val_loss: 1.0212

# %%
model_json = model.to_json()
with open("emotiondetector1.json",'w') as json_file:
    json_file.write(model_json)
model.save("emotiondetector1.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.models import model_from_json

# %%
json_file = open("emotiondetector1.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("emotiondetector1.h5")
# Out:
# I0000 00:00:1741815836.709941     409 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2050, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
label = ['angry','disgust','fear','happy','neutral','sad','surprise']

# %%
def ef(image):
    img = load_img(image,color_mode='grayscale' )
    feature = np.array(img)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

# %%
image = 'images/train/sad/Training_23814.jpg'
print("original image is of sad")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
# Out:
# original image is of sad
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741815849.920821     968 service.cc:148] XLA service 0x7fbc4c004360 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741815849.922871     968 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2050, Compute Capability 8.6
# 2025-03-12 21:44:09.977015: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1741815850.107082     968 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# model prediction is  sad
# I0000 00:00:1741815852.769280     968 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = 'images/test/angry/PrivateTest_731447.jpg'
print("original image is of angry")
img = ef(image)
pred = model.predict(img)
pred_label = label[pred.argmax()]
print("model prediction is ",pred_label)
plt.imshow(img.reshape(48,48),cmap='gray')
# Out:
# original image is of angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# model prediction is  angry

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Get true labels and predicted labels
y_true = np.argmax(y_test, axis=1)  # Convert one-hot to label indices
y_pred = np.argmax(model.predict(x_test), axis=1)

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Compute evaluation metrics
print("Classification Report:")
print(classification_report(y_true, y_pred))

# Compute test accuracy
test_accuracy = accuracy_score(y_true, y_pred)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.57      0.56       958
#            1       0.89      0.50      0.64       111
#            2       0.52      0.43      0.47      1024
#            3       0.83      0.84      0.83      1774
#            4       0.53      0.66      0.59      1233
#            5       0.51      0.48      0.49      1247
#            6       0.80      0.76      0.78       831
#
#     accuracy                           0.64      7178
#    macro avg       0.66      0.61      0.62      7178
# weighted avg       0.64      0.64      0.64      7178
#
# Test Accuracy: 63.62%

# %%
# Plot confusion matrix
plt.figure(figsize=(8,6))
# sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label.values(), yticklabels=label.values())
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label, yticklabels=label)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
